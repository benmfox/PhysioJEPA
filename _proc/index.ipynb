# %% [raw]
# ---
# description: Physiological signal modeling with joint embedding predicting architectures!
# output-file: index.html
# title: PhysioJEPA
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install physiojepa
# ```
