# %% [raw]
# ---
# output-file: heads.html
# title: SSL, Fine Tuning, and Linear Probing Heads
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Linear Probing and Fine Tuning Heads

# %%
#| echo: false
#| output: asis
show_doc(AvgPatchLogisticRegression)
# Out:
# ---
#
# [source](https://github.com/benmfox/PhysioJEPA/blob/main/physiojepa/heads.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### AvgPatchLogisticRegression
#
# >      AvgPatchLogisticRegression (c_in=7, input_size=512,
# >                                  missing_channel_indices=None, dropout=0.0)
#
# *Binary logistic regression with progressive dimension reduction*

# %%
m = AvgPatchLogisticRegression(c_in=7, 
                      input_size = 512, 
                      )

x = torch.randn((4,7,512,3600))
y = torch.randint(0, 2, (4,1))
out = m(x, return_softmax=False)
out.shape
# Out:
# torch.Size([4, 2, 1])
