# %%
#| hide
import physiojepa

# %% [markdown]
# # PhysioJEPA
#
# > Physiological signal modeling with joint embedding predicting architectures!

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install physiojepa
# ```
